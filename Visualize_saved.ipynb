# %%
# Standard library imports
import os

# Third party imports
import matplotlib.pyplot as plt
import numpy as np
import dill

# Local application imports
from smile import helper

# Settings
pickle_dir = r'D:\saved_populations'

# %%
def load_from_file(filename):
    with open(filename, 'rb') as f:
        return dill.load(f)

# %% [markdown]
# ## Experiment: Realistic Methodology
#
# Purpose:
#    * Sampling similarly to what a real clinician would want

# %% [markdown]
# ### Populations

# %%
poplists = load_from_file(pickle_dir+'\poster_poplists_0.pik')

# %%
ncols = 3
nrows = poplists.size
scale = 2

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols*scale*1.5, nrows*scale), squeeze=False, sharex='col', sharey='col')
npersons=None
ndays=None

for row in range(nrows):
    poplists.flatten()[row][0].plot(axes[row, 0], x='day', y='visual', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    poplists.flatten()[row][0].plot(axes[row, 1], x='day', y='symptom', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    poplists.flatten()[row][0].plot(axes[row, 2], x='visual', y='symptom', viztype='points', vizcolor='person', npersons=npersons, ndays=ndays)
    
    for ax in axes[row]: 
        ax.tick_params(labelbottom=True)

plt.tight_layout()
plt.show()

# %%
li = [[poplist.summarize()] for poplist in poplists.flat]
helper.print_collocated(li)
# Out:
# Title: 'list of poster with 1 and 0.3'
# Titles: [... 'poster with 1 and 0.3' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of poster with 1 and 0.5'
# Titles: [... 'poster with 1 and 0.5' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of poster with 2 and 0.3'
# Titles: [... 'poster with 2 and 0.3' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of poster with 2 and 0.5'
# Titles: [... 'poster with 2 and 0.5' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of poster with 3 and 0.3'
# Titles: [... 'poster with 3 and 0.3' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of poster with 3 and 0.5'
# Titles: [... 'poster with 3 and 0.5' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]

# %% [markdown]
# ### Filtering

# %%
filtered_poplists = load_from_file(pickle_dir+'\poster_filtered_poplists_0.pik')

# %%
ncols = 3
nrows = filtered_poplists.size
scale = 2

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols*scale*1.5, nrows*scale), squeeze=False, sharex='col', sharey='col')
npersons=None
ndays=None

for row in range(nrows):
    filtered_poplists.flatten()[row][0].plot(axes[row, 0], x='day', y='visual', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    filtered_poplists.flatten()[row][0].plot(axes[row, 1], x='day', y='symptom', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    filtered_poplists.flatten()[row][0].plot(axes[row, 2], x='visual', y='symptom', viztype='points', vizcolor='person', npersons=npersons, ndays=ndays)
    
    for ax in axes[row]: 
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()

# %%
li = [[poplist.summarize()] for poplist in filtered_poplists.flat]
helper.print_collocated(li)
# Out:
# Title: 'list of poster with 1 and 0.3 filtered'
# Titles: [... 'poster with 1 and 0.3 filtered' ...]
# N Persons: 6329 / 10000 = 0.63
# N Days: [... 160 ...]
#
# Title: 'list of poster with 1 and 0.5 filtered'
# Titles: [... 'poster with 1 and 0.5 filtered' ...]
# N Persons: 3824 / 10000 = 0.38
# N Days: [... 160 ...]
#
# Title: 'list of poster with 2 and 0.3 filtered'
# Titles: [... 'poster with 2 and 0.3 filtered' ...]
# N Persons: 6292 / 10000 = 0.63
# N Days: [... 160 ...]
#
# Title: 'list of poster with 2 and 0.5 filtered'
# Titles: [... 'poster with 2 and 0.5 filtered' ...]
# N Persons: 3820 / 10000 = 0.38
# N Days: [... 160 ...]
#
# Title: 'list of poster with 3 and 0.3 filtered'
# Titles: [... 'poster with 3 and 0.3 filtered' ...]
# N Persons: 6169 / 10000 = 0.62
# N Days: [... 160 ...]
#
# Title: 'list of poster with 3 and 0.5 filtered'
# Titles: [... 'poster with 3 and 0.5 filtered' ...]
# N Persons: 3822 / 10000 = 0.38
# N Days: [... 160 ...]

# %% [markdown]
# ### Sampling

# %%
sampled_poplists = load_from_file(pickle_dir+'\poster_sampled_poplists_0.pik')

# %%
ncols = 3
nrows = sampled_poplists.size
scale = 2

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols*scale*1.5, nrows*scale), squeeze=False, sharex='col', sharey='col')
npersons=None
ndays=None

for row in range(nrows):
    sampled_poplists.flat[row].plot(axes[row, 0], x='day', y='visual', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    sampled_poplists.flat[row].plot(axes[row, 1], x='day', y='symptom', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    sampled_poplists.flat[row].plot(axes[row, 2], x='visual', y='symptom', viztype='points', vizcolor='person', npersons=npersons, ndays=ndays)
    
    for ax in axes[row]: 
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()

# %%
li = [[poplist.summarize()] for poplist in sampled_poplists.flat]
helper.print_collocated(li)
# Out:
# Title: 'poster with 1 and 0.3 filtered \nsampled by traditonal'
# Titles: [... 'poster with 1 and 0.3 filtered \nsampled by traditonal' ...]
# N Persons: 6329 / 10000 = 0.63
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'poster with 1 and 0.3 filtered \nsampled by realistic'
# Titles: [... 'poster with 1 and 0.3 filtered \nsampled by realistic' ...]
# N Persons: 6329 / 10000 = 0.63
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 504, 610), (0, 498, 582), (0, 530, 625), ..., (0, 505, 614), (0, 536, 636), (0, 477, 590)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 0, 3), (0, 0, 3), (0, 0, 1), ..., (0, 0, 2), (0, 0, 0), (0, 0, 5)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'poster with 1 and 0.5 filtered \nsampled by traditonal'
# Titles: [... 'poster with 1 and 0.5 filtered \nsampled by traditonal' ...]
# N Persons: 3824 / 10000 = 0.38
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'poster with 1 and 0.5 filtered \nsampled by realistic'
# Titles: [... 'poster with 1 and 0.5 filtered \nsampled by realistic' ...]
# N Persons: 3824 / 10000 = 0.38
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 161, 210), (0, 160, 212), (0, 150, 189), ..., (0, 158, 203), (0, 162, 220), (0, 153, 209)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 80, 85), (0, 96, 105), (0, 79, 86), ..., (0, 76, 89), (0, 87, 94), (0, 83, 92)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'poster with 2 and 0.3 filtered \nsampled by traditonal'
# Titles: [... 'poster with 2 and 0.3 filtered \nsampled by traditonal' ...]
# N Persons: 6292 / 10000 = 0.63
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'poster with 2 and 0.3 filtered \nsampled by realistic'
# Titles: [... 'poster with 2 and 0.3 filtered \nsampled by realistic' ...]
# N Persons: 6292 / 10000 = 0.63
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 418, 621), (0, 421, 621), (0, 480, 643), ..., (0, 438, 624), (0, 446, 650), (0, 424, 623)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'poster with 2 and 0.5 filtered \nsampled by traditonal'
# Titles: [... 'poster with 2 and 0.5 filtered \nsampled by traditonal' ...]
# N Persons: 3820 / 10000 = 0.38
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'poster with 2 and 0.5 filtered \nsampled by realistic'
# Titles: [... 'poster with 2 and 0.5 filtered \nsampled by realistic' ...]
# N Persons: 3820 / 10000 = 0.38
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 126, 392), (0, 124, 366), (0, 131, 377), ..., (0, 123, 363), (0, 145, 363), (0, 150, 415)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 100, 100), (0, 77, 77), (0, 68, 68), ..., (0, 79, 79), (0, 71, 71), (0, 82, 82)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'poster with 3 and 0.3 filtered \nsampled by traditonal'
# Titles: [... 'poster with 3 and 0.3 filtered \nsampled by traditonal' ...]
# N Persons: 6169 / 10000 = 0.62
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'poster with 3 and 0.3 filtered \nsampled by realistic'
# Titles: [... 'poster with 3 and 0.3 filtered \nsampled by realistic' ...]
# N Persons: 6169 / 10000 = 0.62
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 417, 620), (0, 392, 617), (0, 375, 590), ..., (0, 403, 605), (0, 420, 627), (0, 411, 629)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'poster with 3 and 0.5 filtered \nsampled by traditonal'
# Titles: [... 'poster with 3 and 0.5 filtered \nsampled by traditonal' ...]
# N Persons: 3822 / 10000 = 0.38
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'poster with 3 and 0.5 filtered \nsampled by realistic'
# Titles: [... 'poster with 3 and 0.5 filtered \nsampled by realistic' ...]
# N Persons: 3822 / 10000 = 0.38
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 134, 377), (0, 129, 385), (0, 142, 395), ..., (0, 131, 393), (0, 145, 410), (0, 115, 374)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 59, 59), (0, 76, 76), (0, 59, 59), ..., (0, 83, 83), (0, 75, 75), (0, 77, 77)] -- [... ('raise', 'NaN', 'NaN') ...]

# %% [markdown]
# ## Experiment: Realistic Methodology With different simulation

# %% [markdown]
# ### Populations

# %%
poplists = load_from_file(pickle_dir+'\worddoc_poplists_0.pik')

# %%
ncols = 3
nrows = poplists.size
scale = 2

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols*scale*1.5, nrows*scale), squeeze=False, sharex='col', sharey='col')
npersons=None
ndays=None

for row in range(nrows):
    poplists.flatten()[row][0].plot(axes[row, 0], x='day', y='visual', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    poplists.flatten()[row][0].plot(axes[row, 1], x='day', y='symptom', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    poplists.flatten()[row][0].plot(axes[row, 2], x='visual', y='symptom', viztype='points', vizcolor='person', npersons=npersons, ndays=ndays)
    
    for ax in axes[row]: 
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()

# %%
from smile.global_params import FIRSTVISIT, LASTVISIT
i,j,k = 0,0,1
recovery_times = np.vstack([pop.parameters['v0'] / pop.parameters['r'] for pop in poplists[i,j]])
recovery_times = recovery_times.flatten()
xticks = [0,FIRSTVISIT] + list(range(FIRSTVISIT+1,LASTVISIT+1)) + [LASTVISIT+1, recovery_times.max()+1]
vals, _, _ = plt.hist(recovery_times, bins=xticks, density=True)
plt.xscale("log")
plt.yscale("log")
plt.ylim(top=10**(np.log10(vals.max())+1))
plt.show()

# %%
li = [[poplist.summarize()] for poplist in poplists.flat]
helper.print_collocated(li)
# Out:
# Title: 'list of realistic with 1 and 0.3'
# Titles: [... 'realistic with 1 and 0.3' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 1 and 0.5'
# Titles: [... 'realistic with 1 and 0.5' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 2 and 0.3'
# Titles: [... 'realistic with 2 and 0.3' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 2 and 0.5'
# Titles: [... 'realistic with 2 and 0.5' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 3 and 0.3'
# Titles: [... 'realistic with 3 and 0.3' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 3 and 0.5'
# Titles: [... 'realistic with 3 and 0.5' ...]
# N Persons: 10000 / 10000 = 1.00
# N Days: [... 160 ...]

# %% [markdown]
# ### Filtering

# %%
filtered_poplists = load_from_file(pickle_dir+'\worddoc_filtered_poplists_0.pik')

# %%
ncols = 3
nrows = filtered_poplists.size
scale = 2

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols*scale*1.5, nrows*scale), squeeze=False, sharex='col', sharey='col')
npersons=None
ndays=None

for row in range(nrows):
    filtered_poplists.flatten()[row][0].plot(axes[row, 0], x='day', y='visual', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    filtered_poplists.flatten()[row][0].plot(axes[row, 1], x='day', y='symptom', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    filtered_poplists.flatten()[row][0].plot(axes[row, 2], x='visual', y='symptom', viztype='points', vizcolor='person', npersons=npersons, ndays=ndays)
    
    for ax in axes[row]: 
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()

# %%
li = [[poplist.summarize()] for poplist in filtered_poplists.flat]
helper.print_collocated(li)
# Out:
# Title: 'list of realistic with 1 and 0.3 filtered'
# Titles: [... 'realistic with 1 and 0.3 filtered' ...]
# N Persons: 3485 / 10000 = 0.35
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 1 and 0.5 filtered'
# Titles: [... 'realistic with 1 and 0.5 filtered' ...]
# N Persons: 2521 / 10000 = 0.25
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 2 and 0.3 filtered'
# Titles: [... 'realistic with 2 and 0.3 filtered' ...]
# N Persons: 3478 / 10000 = 0.35
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 2 and 0.5 filtered'
# Titles: [... 'realistic with 2 and 0.5 filtered' ...]
# N Persons: 2570 / 10000 = 0.26
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 3 and 0.3 filtered'
# Titles: [... 'realistic with 3 and 0.3 filtered' ...]
# N Persons: 3472 / 10000 = 0.35
# N Days: [... 160 ...]
#
# Title: 'list of realistic with 3 and 0.5 filtered'
# Titles: [... 'realistic with 3 and 0.5 filtered' ...]
# N Persons: 2489 / 10000 = 0.25
# N Days: [... 160 ...]

# %% [markdown]
# ### Sampling

# %%
sampled_poplists = load_from_file(pickle_dir+'\worddoc_sampled_poplists_0.pik')

# %%
ncols = 3
nrows = sampled_poplists.size
scale = 2

fig, axes = plt.subplots(ncols=ncols, nrows=nrows, figsize=(ncols*scale*1.5, nrows*scale), squeeze=False, sharex='col', sharey='col')
npersons=None
ndays=None

for row in range(nrows):
    sampled_poplists.flat[row].plot(axes[row, 0], x='day', y='visual', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    sampled_poplists.flat[row].plot(axes[row, 1], x='day', y='symptom', viztype='lines', vizcolor='person', npersons=npersons, ndays=ndays)
    sampled_poplists.flat[row].plot(axes[row, 2], x='visual', y='symptom', viztype='points', vizcolor='person', npersons=npersons, ndays=ndays)
    
    for ax in axes[row]: 
        ax.tick_params(labelbottom=True)
    
plt.tight_layout()
plt.show()

# %%
li = [[poplist.summarize()] for poplist in sampled_poplists.flat]
helper.print_collocated(li)
# Out:
# Title: 'realistic with 1 and 0.3 filtered \nsampled by traditonal'
# Titles: [... 'realistic with 1 and 0.3 filtered \nsampled by traditonal' ...]
# N Persons: 3485 / 10000 = 0.35
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'realistic with 1 and 0.3 filtered \nsampled by realistic'
# Titles: [... 'realistic with 1 and 0.3 filtered \nsampled by realistic' ...]
# N Persons: 3485 / 10000 = 0.35
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 83, 1), (0, 82, 0), (0, 86, 2), ..., (0, 81, 0), (0, 85, 4), (0, 68, 3)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 7, 326), (0, 4, 329), (0, 7, 332), ..., (0, 5, 312), (0, 7, 299), (0, 10, 315)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'realistic with 1 and 0.5 filtered \nsampled by traditonal'
# Titles: [... 'realistic with 1 and 0.5 filtered \nsampled by traditonal' ...]
# N Persons: 2521 / 10000 = 0.25
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'realistic with 1 and 0.5 filtered \nsampled by realistic'
# Titles: [... 'realistic with 1 and 0.5 filtered \nsampled by realistic' ...]
# N Persons: 2521 / 10000 = 0.25
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 30, 0), (0, 24, 0), (0, 31, 0), ..., (0, 26, 0), (0, 26, 0), (0, 34, 0)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 38, 259), (0, 32, 235), (0, 30, 231), ..., (0, 30, 263), (0, 29, 249), (0, 40, 266)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'realistic with 2 and 0.3 filtered \nsampled by traditonal'
# Titles: [... 'realistic with 2 and 0.3 filtered \nsampled by traditonal' ...]
# N Persons: 3478 / 10000 = 0.35
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'realistic with 2 and 0.3 filtered \nsampled by realistic'
# Titles: [... 'realistic with 2 and 0.3 filtered \nsampled by realistic' ...]
# N Persons: 3478 / 10000 = 0.35
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 71, 11), (0, 94, 20), (0, 90, 15), ..., (0, 77, 26), (0, 83, 17), (0, 85, 15)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 5, 171), (0, 2, 145), (0, 5, 155), ..., (0, 5, 145), (0, 7, 161), (0, 4, 153)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'realistic with 2 and 0.5 filtered \nsampled by traditonal'
# Titles: [... 'realistic with 2 and 0.5 filtered \nsampled by traditonal' ...]
# N Persons: 2570 / 10000 = 0.26
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'realistic with 2 and 0.5 filtered \nsampled by realistic'
# Titles: [... 'realistic with 2 and 0.5 filtered \nsampled by realistic' ...]
# N Persons: 2570 / 10000 = 0.26
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 25, 6), (0, 29, 6), (0, 34, 13), ..., (0, 26, 11), (0, 30, 10), (0, 32, 4)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 25, 159), (0, 33, 165), (0, 35, 196), ..., (0, 21, 141), (0, 28, 167), (0, 38, 159)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'realistic with 3 and 0.3 filtered \nsampled by traditonal'
# Titles: [... 'realistic with 3 and 0.3 filtered \nsampled by traditonal' ...]
# N Persons: 3472 / 10000 = 0.35
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'realistic with 3 and 0.3 filtered \nsampled by realistic'
# Titles: [... 'realistic with 3 and 0.3 filtered \nsampled by realistic' ...]
# N Persons: 3472 / 10000 = 0.35
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 81, 20), (0, 83, 21), (0, 88, 26), ..., (0, 87, 26), (0, 93, 23), (0, 95, 24)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 6, 79), (0, 7, 104), (0, 5, 86), ..., (0, 4, 103), (0, 8, 90), (0, 6, 92)] -- [... ('raise', 'NaN', 'NaN') ...]
#
# Title: 'realistic with 3 and 0.5 filtered \nsampled by traditonal'
# Titles: [... 'realistic with 3 and 0.5 filtered \nsampled by traditonal' ...]
# N Persons: 2489 / 10000 = 0.25
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
# Already reached: [... (0, 0, 0) ...] -- [... ('raise', 'raise', 'raise') ...]
#
# Title: 'realistic with 3 and 0.5 filtered \nsampled by realistic'
# Titles: [... 'realistic with 3 and 0.5 filtered \nsampled by realistic' ...]
# N Persons: 2489 / 10000 = 0.25
# N Samplers: [... 3 ...] / [... 160 ...]
# Reached limits: [(0, 26, 13), (0, 26, 10), (0, 33, 15), ..., (0, 27, 17), (0, 25, 15), (0, 19, 8)] -- [... ('raise', 'clip', 'clip') ...]
# Already reached: [(0, 37, 149), (0, 27, 88), (0, 20, 104), ..., (0, 38, 119), (0, 34, 120), (0, 43, 118)] -- [... ('raise', 'NaN', 'NaN') ...]
